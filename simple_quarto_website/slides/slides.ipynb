# %% [markdown]
# ---
# title: "My First Presentation"
# author: "Alex Garcia"
# format:
#     revealjs:
#         code-fold: true
# bibliography: reference.bib
# ---
#
# ## COVID Article
# > The use of online platforms such as Google Classroom, Zoom, virtual learning environment and social media and various group forums like Telegram, Messenger, WhatsApp and WeChat are explored and tried for teaching and learning for the first time ever to continue education. This can be explored further even after face-to-face teaching resumes, and these platforms can provide additional resources and coaching to the learners.
#
# ::: {#refs}
# @pokhrel2021literature
# :::
#
# ## Caroline Polachek
# - Albums since 2020:
# - Desire, I Wanna Turn Into You (2023)
#
# <img src="images/caroline.png" alt="A photo of Caroline Polachek." width="285" height="400">
#
# ## Charli XCX
# - Albums since 2020:
# - Brat (2024)
# - Crash (2022)
# - How I'm Feeling Now (2020)
#
# <img src="images/charli.png" alt="A photo of Charli XCX." width="228" height="320">

# %%
import matplotlib.pyplot as plt
x = [0,1,2,3,4]
y = [1,1,2,6,24]

plt.plot(x,y)
plt.xlabel("X")
plt.ylabel("X! on the interval [0,4]")
plt.show()
